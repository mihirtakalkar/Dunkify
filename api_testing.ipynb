# %% [markdown]
# # NBA API Client Usage
#
# The NBA API client used in this project is sourced from the [nba_api](https://github.com/swar/nba_api) repository on GitHub. This Python package provides convenient access to the NBA Stats API, providing retrieval of NBA-related data in our application.
#
# To incorporate the NBA API client into our project, we followed the documentation and guidelines provided by the repository. The client enables us to fetch a variety of data, including player statistics, team information, game results, and more.
#
# For detailed information on the NBA API client and its capabilities, please refer to the official [nba_api GitHub repository](https://github.com/swar/nba_api).

# %%
pip install nba_api
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nba_api in /Users/mihir/Library/Python/3.9/lib/python/site-packages (1.4.1)
# Requirement already satisfied: certifi<2024.0.0,>=2023.7.22 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from nba_api) (2023.11.17)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from nba_api) (1.26.2)
# Requirement already satisfied: requests<3.0,>=2.31 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from nba_api) (2.31.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.31->nba_api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.31->nba_api) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.31->nba_api) (3.3.2)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/mihir/Library/Python/3.9/lib/python/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/mihir/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import teams
from nba_api.stats.static import players
import pandas
import numpy as np

# %% [markdown]
# ### Individual Career Data

# %%
# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print("Number of players fetched: {}".format(len(nba_players)))
nba_players[:5]
lebron = [player for player in nba_players if player["full_name"] == "LeBron James"] 
lebron
adavis = [player for player in nba_players if player["full_name"] == "Anthony Davis"] 
adavis
# Out:
# Number of players fetched: 4900
# [{'id': 203076,
#   'full_name': 'Anthony Davis',
#   'first_name': 'Anthony',
#   'last_name': 'Davis',
#   'is_active': True}]

# %%
#player awards
from nba_api.stats.endpoints import playerawards
adavis_awards = playerawards.PlayerAwards(player_id="203076")
adavis_awards.get_data_frames()
# Out:
# [    PERSON_ID FIRST_NAME LAST_NAME                  TEAM  \
#  0      203076    Anthony     Davis  New Orleans Pelicans
#  1      203076    Anthony     Davis  New Orleans Pelicans
#  2      203076    Anthony     Davis    Los Angeles Lakers
#  3      203076    Anthony     Davis  New Orleans Pelicans
#  4      203076    Anthony     Davis  New Orleans Pelicans
#  5      203076    Anthony     Davis  New Orleans Pelicans
#  6      203076    Anthony     Davis    Los Angeles Lakers
#  7      203076    Anthony     Davis  New Orleans Pelicans
#  8      203076    Anthony     Davis  New Orleans Pelicans
#  9      203076    Anthony     Davis  New Orleans Pelicans
#  10     203076    Anthony     Davis  New Orleans Pelicans
#  11     203076    Anthony     Davis  New Orleans Pelicans
#  12     203076    Anthony     Davis  New Orleans Pelicans
#  13     203076    Anthony     Davis  New Orleans Pelicans
#  14     203076    Anthony     Davis  New Orleans Pelicans
#  15     203076    Anthony     Davis  New Orleans Pelicans
#  16     203076    Anthony     Davis    Los Angeles Lakers
#  17     203076    Anthony     Davis    Los Angeles Lakers
#  18     203076    Anthony     Davis                   USA
LAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# 11       2544   2014-15        00  1610612739               CLE        30.0
# 12       2544   2015-16        00  1610612739               CLE        31.0
# 13       2544   2016-17        00  1610612739               CLE        32.0
# 14       2544   2017-18        00  1610612739               CLE        33.0
# 15       2544   2018-19        00  1610612747               LAL        34.0
# 16       2544   2019-20        00  1610612747               LAL        35.0
# 17       2544   2020-21        00  1610612747               LAL        36.0
# 18       2544   2021-22        00  1610612747               LAL        37.0
# 19       2544   2022-23        00  1610612747               LAL        38.0
# 20       2544   2023-24        00  1610612747               LAL        38.0
#
#     GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0   79  79  3120.0  622  ...   0.754    99   333  432  465  130   58  273
# 1   80  80  3388.0  795  ...   0.750   111   477  588  577  177   52  262
# 2   79  79  3361.0  875  ...   0.738    75   481  556  521  123   66  260
# 3   78  78  3190.0  772  ...   0.698    83   443  526  470  125   55  250
# 4   75  74  3027.0  794  ...   0.712   133   459  592  539  138   81  255
# 5   81  81  3054.0  789  ...   0.780   106   507  613  587  137   93  241
# 6   76  76  2966.0  768  ...   0.767    71   483  554  651  125   77  261
# 7   79  79  3063.0  758  ...   0.759    80   510  590  554  124   50  284
# 8   62  62  2326.0  621  ...   0.771    94   398  492  387  115   50  213
# 9   76  76  2877.0  765  ...   0.753    97   513  610  551  129   67  226
# 10  77  77  2902.0  767  ...   0.750    81   452  533  488  121   26  270
# 11  69  69  2493.0  624  ...   0.710    51   365  416  511  109   49  272
# 12  76  76  2709.0  737  ...   0.731   111   454  565  514  104   49  249
# 13  74  74  2795.0  736  ...   0.674    97   542  639  646   92   44  303
# 14  82  82  3026.0  857  ...   0.731    97   612  709  747  116   71  347
# 15  55  55  1937.0  558  ...   0.665    57   408  465  454   72   33  197
# 16  67  67  2316.0  643  ...   0.693    66   459  525  684   78   36  261
# 17  45  45  1504.0  422  ...   0.698    29   317  346  350   48   25  168
# 18  56  56  2084.0  640  ...   0.756    63   396  459  349   73   59  196
# 19  55  54  1954.0  609  ...   0.768    65   392  457  375   50   32  178
# 20  28  28   960.0  263  ...   0.742    28   189  217  204   41   20   94
#
#      PF   PTS
# 0   149  1654
# 1   146  2175
# 2   181  2478
# 3   171  2132
# 4   165  2250
# 5   139  2304
# 6   119  2258
# 7   163  2111
# 8    96  1683
# 9   110  2036
# 10  126  2089
# 11  135  1743
# 12  143  1920
# 13  134  1954
# 14  136  2251
# 15   94  1505
# 16  118  1698
# 17   70  1126
# 18  121  1695
# 19   88  1590
# 20   29   711
#
# [21 rows x 27 columns]

# %% [markdown]
# ### All-Time Stats

# %%
#all-time leaders endpoint
from nba_api.stats.endpoints import alltimeleadersgrids
leaders = alltimeleadersgrids.AllTimeLeadersGrids()
assists.get_data_frames()[2]
# Out:
#    PLAYER_ID        PLAYER_NAME    AST  AST_RANK IS_ACTIVE_FLAG
# 0        304      John Stockton  15806         1              N
# 1        467         Jason Kidd  12091         2              N
# 2     101108         Chris Paul  11707         3              Y
# 3       2544       LeBron James  10624         4              Y
# 4        959         Steve Nash  10335         5              N
# 5        349       Mark Jackson  10334         6              N
# 6      77142      Magic Johnson  10141         7              N
# 7     600015    Oscar Robertson   9887         8              N
# 8     201566  Russell Westbrook   9303         9              Y
# 9      78318       Isiah Thomas   9061        10              N

# %% [markdown]
# ### Player Game Timelines

# %%
#next games
from nba_api.stats.endpoints import playernextngames
nextGames = playernextngames.PlayerNextNGames(number_of_games=10, player_id="2544")
nextGames.get_data_frames()
# Out:
# [      GAME_ID     GAME_DATE  HOME_TEAM_ID  VISITOR_TEAM_ID HOME_TEAM_NAME  \
#  0  0022300428  DEC 28, 2023    1610612747       1610612766    L.A. Lakers
#  1  0022300443  DEC 30, 2023    1610612750       1610612747      Minnesota
#  2  0022300446  DEC 31, 2023    1610612740       1610612747    New Orleans
#  3  0022300475  JAN 03, 2024    1610612747       1610612748    L.A. Lakers
#  4  0022300491  JAN 05, 2024    1610612747       1610612763    L.A. Lakers
#  5  0022300505  JAN 07, 2024    1610612747       1610612746    L.A. Lakers
#  6  0022300516  JAN 09, 2024    1610612747       1610612761    L.A. Lakers
#  7  0022300531  JAN 11, 2024    1610612747       1610612756    L.A. Lakers
#  8  0022300549  JAN 13, 2024    1610612762       1610612747           Utah
#  9  0022300565  JAN 15, 2024    1610612747       1610612760    L.A. Lakers
#
#    VISITOR_TEAM_NAME HOME_TEAM_ABBREVIATION VISITOR_TEAM_ABBREVIATION  \
#  0         Charlotte                    LAL                       CHA
#  1       L.A. Lakers                    MIN                       LAL
#  2       L.A. Lakers                    NOP                       LAL
#  3             Miami                    LAL                       MIA
#  4           Memphis                    LAL                       MEM
#  5       LA Clippers                    LAL                       LAC
#  6           Toronto                    LAL                       TOR
#  7           Phoenix                    LAL                       PHX
#  8       L.A. Lakers                    UTA                       LAL
#  9     Oklahoma City                    LAL                       OKC
#
#    HOME_TEAM_NICKNAME VISITOR_TEAM_NICKNAME GAME_TIME HOME_WL VISITOR_WL
#  0             Lakers               Hornets  10:30 PM   16-15       7-21
#  1       Timberwolves                Lakers  08:00 PM    22-7      16-15
#  2           Pelicans                Lakers  07:00 PM   17-14      16-15
#  3             Lakers                  Heat  10:00 PM   16-15      18-12
#  4             Lakers             Grizzlies  10:00 PM   16-15      10-19
#  5             Lakers              Clippers  09:30 PM   16-15      18-12
#  6             Lakers               Raptors  10:30 PM   16-15      11-18
#  7             Lakers                  Suns  10:00 PM   16-15      14-15
#  8               Jazz                Lakers  09:30 PM   13-18      16-15
#  9             Lakers               Thunder  10:30 PM   16-15       19-9  ]

# %%
#previous games dashboard
from nba_api.stats.endpoints import playerdashboardbylastngames
prevGames = playerdashboardbylastngames.PlayerDashboardByLastNGames(last_n_games=2, player_id="2544")
prevGames.get_data_frames()
# Out:
# [  GROUP_SET GROUP_VALUE  GP  W  L  W_PCT        MIN  FGM  FGA  FG_PCT  ...  \
#  0   Overall     2023-24   2  1  1    0.5  74.093333   18   34   0.529  ...
#
#     BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
#  0         1          1        1         1         1                1
#
#     NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK
#  0                     1         1         1                      1
#
#  [1 rows x 62 columns],
#        GROUP_SET GROUP_VALUE  GP  W  L  W_PCT        MIN  FGM  FGA  FG_PCT  \
#  0  Last 5 Games     2023-24   2  1  1    0.5  74.093333   18   34   0.529
#
#     ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
#  0  ...         1          1        1         1         1                1
#
#     NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK
#  0                     1         1         1                      1
#
#  [1 rows x 62 columns],
#         GROUP_SET GROUP_VALUE  GP  W  L  W_PCT        MIN  FGM  FGA  FG_PCT  \
#  0  Last 10 Games     2023-24   2  1  1    0.5  74.093333   18   34   0.529
#
#     ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
#  0  ...         1          1        1         1         1                1
#
#     NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK
#  0                     1         1         1                      1
#
#  [1 rows x 62 columns],
#         GROUP_SET GROUP_VALUE  GP  W  L  W_PCT        MIN  FGM  FGA  FG_PCT  \
#  0  Last 15 Games     2023-24   2  1  1    0.5  74.093333   18   34   0.529
#
#     ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
#  0  ...         1          1        1         1         1                1
#
#     NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK
#  0                     1         1         1                      1
#
#  [1 rows x 62 columns],
#         GROUP_SET GROUP_VALUE  GP  W  L  W_PCT        MIN  FGM  FGA  FG_PCT  \
#  0  Last 20 Games     2023-24   2  1  1    0.5  74.093333   18   34   0.529
#
#     ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
#  0  ...         1          1        1         1         1                1
#
#     NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK
#  0                     1         1         1                      1
#
#  [1 rows x 62 columns],
#       GROUP_SET  GROUP_VALUE  GP  W  L  W_PCT        MIN  FGM  FGA  FG_PCT  \
#  0  Game Number  Games 21-30   1  1  0    1.0  37.310000   13   20   0.650
#  1  Game Number  Games 31-40   1  0  1    0.0  36.783333    5   14   0.357
#
#     ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
#  0  ...         1          1        1         1         1                1
#  1  ...         2          1        2         2         2                2
#
#     NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK
#  0                     1         1         1                      1
#  1                     2         1         1                      2
#
#  [2 rows x 62 columns]]
